# %%
from bs4 import BeautifulSoup as bs
import requests 
import re 
import time
import datetime

for i in range(659, 1000):
    today = datetime.date.today()
    today = today + datetime.timedelta(-i)
    today = ("").join(str(today).split('-'))
    print(today)
    naver_news_today= "http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date={}".format(today)
    print(naver_news_today)
    res = requests.get(naver_news_today)
    soup = bs(res.content, 'html.parser')
    try:
    # 링크 추출 
        rinks = []
        top3 = soup.find('div', class_="ranking_top3")
        top3 = top3.select("a[href]")
        for top in top3:
            rinks.append(re.search('/main/\w+/\w+[.a-zA-Z?=&0-9;_]+', top['href']).group())
        rinks = rinks[::2]

        for rank in range(4,31):
            all_= soup.find('li', class_="gnum{}".format(rank))
            all_ = all_.select("a[href]")
            for al in all_:
                rinks.append(re.search('/main/\w+/\w+[.a-zA-Z?=&0-9_]+', al['href']).group())
        # 기사 내용 추출 and 합치기
        articles = '{}'.format(today)
        if i == 400:
            for z, rink in enumerate(rinks):
                res = requests.get(base_url+rink)
                soup = bs(res.content, 'html.parser')
                if z == 0:
                    article = re.sub(r'[\n]', '',soup.find("div", id="articeBody").text)
                else:
                    article = re.sub(r'[\n]', '',soup.find("div", id="articleBodyContents").text)
                article = re.sub(r'[\w0-9a-zA-Z_.-]@[\w0-9a-zA-Z_.-]', '', article)
                article = re.sub(r'\w+\.\w+.\w+', '', article)
                article = re.sub(r'무단전재 및 재배포 금지', '', article)
                article = re.sub(r'▶.*', '', article )
                articles += article 
        elif i == 629:
            for z, rink in enumerate(rinks):
                res = requests.get(base_url+rink)
                soup = bs(res.content, 'html.parser')
                if z == 19:
                    article = re.sub(r'[\n]', '',soup.find("div", id="newsEndContents").text)
                else:
                    article = re.sub(r'[\n]', '',soup.find("div", id="articleBodyContents").text)
                article = re.sub(r'[\w0-9a-zA-Z_.-]@[\w0-9a-zA-Z_.-]', '', article)
                article = re.sub(r'\w+\.\w+.\w+', '', article)
                article = re.sub(r'무단전재 및 재배포 금지', '', article)
                article = re.sub(r'▶.*', '', article )
                articles += article 


        else : 
            for rink in rinks:
                res = requests.get(base_url+rink)
                soup = bs(res.content, 'html.parser')
                article = re.sub(r'[\n]', '', soup.find("div", id="articleBodyContents").text)
                article = re.sub(r'[\w0-9a-zA-Z_.-]@[\w0-9a-zA-Z_.-]', '', article)
                article = re.sub(r'\w+\.\w+.\w+', '', article)
                article = re.sub(r'무단전재 및 재배포 금지', '', article)
                article = re.sub(r'▶.*', '', article )
                articles += article 
        # 일별로 파일 작성 
        with open("article{}.txt".format(i), "w") as f:
            f.write(articles)
        
    except : 
        print("{} is missed".format(i))
# Out:
# 20160223
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160223
# 659 is missed
# 20160222
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160222
# 660 is missed
# 20160221
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160221
# 661 is missed
# 20160220
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160220
# 662 is missed
# 20160219
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160219
# 663 is missed
# 20160218
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160218
# 664 is missed
# 20160217
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160217
# 665 is missed
# 20160216
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160216
# 666 is missed
# 20160215
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160215
# 667 is missed
# 20160214
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160214
# 668 is missed
# 20160213
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160213
# 669 is missed
# 20160212
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160212
# 670 is missed
# 20160211
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160211
# 671 is missed
# 20160210
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160210
# 672 is missed
# 20160209
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160209
# 673 is missed
# 20160208
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160208
# 674 is missed
# 20160207
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160207
# 675 is missed
# 20160206
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160206
# 676 is missed
# 20160205
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160205
# 677 is missed
# 20160204
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160204
# 678 is missed
# 20160203
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160203
# 679 is missed
# 20160202
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160202
# 680 is missed
# 20160201
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160201
# 681 is missed
# 20160131
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160131
# 682 is missed
# 20160130
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160130
# 683 is missed
# 20160129
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160129
# 684 is missed
# 20160128
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160128
# 685 is missed
# 20160127
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160127
# 686 is missed
# 20160126
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160126
# 687 is missed
# 20160125
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160125
# 688 is missed
# 20160124
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160124
# 689 is missed
# 20160123
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160123
# 690 is missed
# 20160122
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160122
# 691 is missed
# 20160121
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160121
# 692 is missed
# 20160120
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160120
# 693 is missed
# 20160119
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160119
# 694 is missed
# 20160118
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160118
# 695 is missed
# 20160117
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160117
# 696 is missed
# 20160116
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160116
# 697 is missed
# 20160115
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160115
# 698 is missed
# 20160114
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160114
# 699 is missed
# 20160113
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160113
# 700 is missed
# 20160112
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160112
# 701 is missed
# 20160111
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160111
# 702 is missed
# 20160110
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160110
# 703 is missed
# 20160109
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160109
# 704 is missed
# 20160108
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160108
# 705 is missed
# 20160107
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160107
# 706 is missed
# 20160106
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160106
# 707 is missed
# 20160105
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160105
# 708 is missed
# 20160104
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160104
# 709 is missed
# 20160103
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160103
# 710 is missed
# 20160102
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160102
# 711 is missed
# 20160101
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20160101
# 712 is missed
# 20151231
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151231
# 713 is missed
# 20151230
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151230
# 714 is missed
# 20151229
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151229
# 715 is missed
# 20151228
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151228
# 716 is missed
# 20151227
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151227
# 717 is missed
# 20151226
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151226
# 718 is missed
# 20151225
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151225
# 719 is missed
# 20151224
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151224
# 720 is missed
# 20151223
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151223
# 721 is missed
# 20151222
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151222
# 722 is missed
# 20151221
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151221
# 723 is missed
# 20151220
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151220
# 724 is missed
# 20151219
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151219
# 725 is missed
# 20151218
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151218
# 726 is missed
# 20151217
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151217
# 727 is missed
# 20151216
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151216
# 728 is missed
# 20151215
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151215
# 729 is missed
# 20151214
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151214
# 730 is missed
# 20151213
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151213
# 731 is missed
# 20151212
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151212
# 732 is missed
# 20151211
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151211
# 733 is missed
# 20151210
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151210
# 734 is missed
# 20151209
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151209
# 735 is missed
# 20151208
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151208
# 736 is missed
# 20151207
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151207
# 737 is missed
# 20151206
# http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date=20151206
# ---------------------
# TypeErrorTraceback (most recent call last)
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-4-5899f3dc975d> in <module>()
#      12     naver_news_today= "http://news.naver.com/main/ranking/popularDay.nhn?rankingType=popular_day&sectionId=101&date={}".format(today)
#      13     print(naver_news_today)
# ---> 14     res = requests.get(naver_news_today)
#      15     soup = bs(res.content, 'html.parser')
#      16     try:
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/MAC/.pyenv/versions/anaconda3-4.4.0/envs/python_al/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
soup.find('li')
# Out:
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="http://entertain.naver.com/home"><img alt="TV연예" height="19" src="http://static.news.naver.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
